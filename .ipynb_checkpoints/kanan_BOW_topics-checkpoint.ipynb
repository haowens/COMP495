# %%
import pandas as pd
import numpy as np
import json
import glob
import csv
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import spacy
from nltk.corpus import stopwords
import pyLDAvis
import pyLDAvis.gensim
import pyLDAvis.gensim_models

# %%
def load_data(file):
    with open (file, "r", encoding="utf-8") as f:
        data = json.load(f)
    return (data)

def write_data(file, data):
    with open (file, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4)

# %%
stopwords = stopwords.words("english")
stopwords.append("be")
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'be']

# %%
# Load the JSON data from the file
with open("kg_transcripts.json", "r") as file:
    data = json.load(file)

# Get the keys of the JSON object
fields = data.keys()

# Print the fields
print(fields)
# Out:
# dict_keys(['Transcripts'])

# %%
data = load_data("kg_transcripts.json")["Transcripts"]
print (data[0][0:90])
print (data[1][0:90])
# Out:
# Good evening. Hello. How are you? It's great to be back in India. I've been traveling the
# That's a formal letter. Informal letters, letters you write to your friends, also have a c

# %%
def lemmatization(texts, allowed_postages=["NOUN", "ADJ", "VERB", "ADV"]):
    nlp = nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
    texts_out = []
    for text in data:
        doc = nlp(text)
        new_text = []
        for token in doc:
            if token.pos_ in allowed_postages:
                new_text.append(token.lemma_)
        final = " ".join(new_text)
        texts_out.append(final)
    return (texts_out)

lemmatized_texts = lemmatization(data)
print (lemmatized_texts[0][0:150])
# Out:
# good evening great back travel world lot year good back need small talk good thing look know eye just walk right deserve interaction so case other cou

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'write', 'make', 'take', 'subject', 're', 'edu', 'use', 'be', 'know', 'go', 'think', 'come', 'see', 'guy', 'say', 'even', 'year', 'one', 'would', 'find', 'get'])
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) 
             if word not in stop_words] for doc in texts]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alisha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def gen_words(data):
    final = []
    for text in data:
        new = gensim.utils.simple_preprocess(text, deacc=True)
        final.append(new)
    return (final)

data_words = gen_words(lemmatized_texts)

print (data_words[0][0:20])
print (data_words[1][0:20])
# Out:
# ['good', 'evening', 'great', 'back', 'travel', 'world', 'lot', 'year', 'good', 'back', 'need', 'small', 'talk', 'good', 'thing', 'look', 'know', 'eye', 'just', 'walk']
# ['formal', 'letter', 'informal', 'letter', 'letter', 'write', 'friend', 'also', 'correct', 'way', 'wrong', 'way', 'date', 'left', 'date', 'left', 'kind', 'friend', 'go', 'scrutinize']

# %%
data_words = remove_stopwords(data_words)
print(data_words[:1][0][:30])
# Out:
# ['good', 'evening', 'great', 'back', 'travel', 'world', 'lot', 'good', 'back', 'need', 'small', 'talk', 'good', 'thing', 'look', 'eye', 'walk', 'right', 'deserve', 'interaction', 'case', 'country', 'coffee', 'national', 'sport', 'whole', 'walk', 'first', 'good', 'thank']

# %%
#BIGRAMS AND TRIGRAMS
bigram_phrases = gensim.models.Phrases(data_words, min_count=5, threshold=200)
trigram_phrases = gensim.models.Phrases(bigram_phrases[data_words], threshold=100)

bigram = gensim.models.phrases.Phraser(bigram_phrases)
trigram = gensim.models.phrases.Phraser(trigram_phrases)

def make_bigrams(texts):
    return([bigram[doc] for doc in texts])

def make_trigrams(texts):
    return ([trigram[bigram[doc]] for doc in texts])

data_bigrams = make_bigrams(data_words)
data_bigrams_trigrams = make_trigrams(data_bigrams)

print (data_bigrams_trigrams[0])
# Out:
# ['good', 'evening', 'great', 'back', 'travel', 'world', 'lot', 'good', 'back', 'need', 'small', 'talk', 'good', 'thing', 'look', 'eye', 'walk', 'right', 'deserve', 'interaction', 'case', 'country', 'coffee', 'national', 'sport', 'whole', 'walk', 'first', 'good', 'thank', 'good', 'well', 'hot', 'outside', 'hot', 'begin', 'speak', 'much', 'time', 'population', 'double', 'small', 'talk', 'big', 'talk', 'talk', 'aunty', 'beta', 'yearly', 'salary', 'away', 'long', 'back', 'different', 'airport', 'silent', 'airport', 'announcement', 'airport', 'anymore', 'reason', 'announcement', 'announcement', 'lady', 'gentleman', 'want', 'let', 'happen', 'minute', 'prevent', 'noise', 'pollution', 'snicker', 'big', 'problem', 'country', 'run', 'water', 'least', 'die', 'quietly', 'prevent', 'noise', 'pollution', 'announcement', 'people', 'still', 'catch', 'flight', 'send', 'airline', 'personally', 'scream', 'face', 'noise', 'pollution', 'prevent', 'simple', 'announcement', 'passenger', 'report', 'gate', 'number', 'walk', 'around', 'seem', 'fan', 'airline', 'sometimes', 'look', 'particular', 'passenger', 'man', 'stand', 'yelling', 'look', 'couple', 'fight', 'stand', 'leave', 'promise', 'keep', 'thank', 'watch', 'show', 'good', 'time', 'pass', 'watch', 'comedy', 'indian', 'concept', 'time', 'pass', 'time', 'pass', 'activity', 'review', 'activity', 'work', 'way', 'time', 'pass', 'show', 'time', 'pass', 'bad', 'thing', 'show', 'show', 'feel', 'passage', 'time', 'time', 'pass', 'show', 'mean', 'time', 'pass', 'worry', 'time', 'pass', 'pastime', 'whole', 'different', 'thing', 'hobby', 'pass', 'time', 'people', 'pastime', 'actually', 'read', 'writing', 'time', 'pass', 'first', 'late', 'meeting', 'time', 'relative', 'uncle', 'snicker', 'pj', 'admit', 'also', 'indian', 'concept', 'way', 'pjs', 'poor', 'joke', 'embodiment', 'much', 'country', 'enjoy', 'suffer', 'pj', 'tell', 'laugh', 'person', 'become', 'angry', 'derive', 'enjoyment', 'disappointment', 'usually', 'awful', 'pun', 'right', 'city', 'enter', 'ethnicity', 'mutter', 'expect', 'laughter', 'teach', 'expect', 'let', 'probably', 'wonder', 'blackboard', 'keep', 'blackboard', 'indian', 'people', 'pay', 'attention', 'blackboard', 'texting', 'exam', 'show', 'show', 'basically', 'letter', 'list', 'goal', 'thing', 'accomplish', 'different', 'age', 'read', 'voice', 'bracket', 'future', 'past', 'lamer', 'remember', 'previous', 'version', 'personality', 'summer', 'shake', 'hand', 'area', 'walk', 'public', 'toilet', 'lid', 'closed', 'terrible', 'happen', 'previous', 'person', 'leave', 'face', 'letter', 'bracket', 'future', 'goal', 'formal', 'letter', 'remember', 'kind', 'letters', 'formal', 'letter', 'informal', 'letter', 'distinguish', 'format', 'format', 'formal', 'letter', 'comma', 'fuck', 'comma', 'address', 'letter', 'reach', 'forget', 'mark', 'body', 'letter', 'fuck', 'shit', 'want', 'matter', 'end', 'sincerely', 'want', 'romantic', 'word', 'sincerely', 'sincere']

# %%
# TF-IDF REMOVAL
from gensim.models import TfidfModel

id2word = corpora.Dictionary(data_bigrams_trigrams)

texts = data_bigrams_trigrams

corpus = [id2word.doc2bow(text) for text in texts]
print (corpus[0][0:20])

tfidf = TfidfModel(corpus, id2word=id2word)

low_value = 0.03
words = []
words_missing_in_tfidf = []
for i in range (0, len(corpus)):
    bow = corpus[i]
    low_value_words = [] # reinitialization to be safe, you can skip this
    tfidf_ids = [id for id, value in bow]
    bow_ids = [id for id, value in bow]
    low_value_words = [id for id, value in tfidf[bow] if value < low_value]
    drops = low_value_words+words_missing_in_tfidf
    for item in drops:
        words.append(id2word[item])
    words_missing_in_tfidf = [id for id in bow_ids if id not in tfidf_ids] # the words with tf-idf score 0 will be missing
    
    new_bow = [b for b in bow if b[0] not in low_value_words and b[0] not in words_missing_in_tfidf]
    corpus[i] = new_bow
# Out:
# [(0, 1), (1, 2), (2, 1), (3, 1), (4, 1), (5, 1), (6, 2), (7, 3), (8, 1), (9, 1), (10, 5), (11, 1), (12, 1), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 3), (19, 1)]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, 
                                           id2word=id2word,
                                           num_topics=4,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha="auto")

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.021*"song" + 0.020*"feel" + 0.020*"band" + 0.017*"play" + 0.017*"metaphor" + 0.016*"sad" + 0.016*"software" + 0.013*"friend" + 0.013*"cover" + 0.012*"time"'),
#  (1,
#   '0.020*"dog" + 0.016*"stab" + 0.015*"time" + 0.014*"play" + 0.013*"goal" + 0.012*"lose" + 0.012*"people" + 0.011*"thing" + 0.011*"game" + 0.010*"good"'),
#  (2,
#   '0.027*"time" + 0.020*"pass" + 0.017*"letter" + 0.015*"show" + 0.013*"good" + 0.010*"announcement" + 0.009*"thing" + 0.009*"talk" + 0.008*"walk" + 0.007*"people"'),
#  (3,
#   '0.026*"letter" + 0.022*"doctor" + 0.017*"friend" + 0.012*"goal" + 0.012*"study" + 0.012*"pant" + 0.010*"tell" + 0.009*"feel" + 0.009*"great" + 0.009*"cough"')]

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word, mds="mmds", R=7)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.150645  0.020735       1        1  36.437624
# 0      0.028932  0.147375       2        1  30.839549
# 3      0.136232 -0.065506       3        1  19.208739
# 2     -0.014519 -0.102604       4        1  13.514088, topic_info=             Term       Freq      Total Category  logprob  loglift
# 645          song  13.000000  13.000000  Default   7.0000   7.0000
# 239        doctor   8.000000   8.000000  Default   6.0000   6.0000
# 705          band  13.000000  13.000000  Default   5.0000   5.0000
# 240           dog  15.000000  15.000000  Default   4.0000   4.0000
# 110          pass   6.000000   6.000000  Default   3.0000   3.0000
# 89         letter  22.000000  22.000000  Default   2.0000   2.0000
# 561      metaphor  10.000000  10.000000  Default   1.0000   1.0000
# 240           dog  14.726410  15.286272   Topic1  -3.9116   0.9723
# 297          lose   8.616690   9.132967   Topic1  -4.4476   0.9514
# 508          game   7.838237   8.362722   Topic1  -4.5423   0.9448
# 232           day   7.082480   7.594188   Topic1  -4.6437   0.9398
# 331         phone   7.081220   7.594109   Topic1  -4.6438   0.9396
# 268          give   6.315140   6.824927   Topic1  -4.7583   0.9319
# 157         speak   6.314628   6.825245   Topic1  -4.7584   0.9318
# 649          stab  11.680684  15.876907   Topic1  -4.1433   0.7026
# 600          play  10.148967  20.934382   Topic1  -4.2839   0.2855
# 170          time  10.924932  27.192768   Topic1  -4.2102   0.0977
# 68           goal   9.389480  21.314170   Topic1  -4.3617   0.1898
# 116        people   8.607498  19.285172   Topic1  -4.4487   0.2029
# 645          song  13.335506  13.869241   Topic2  -3.8441   1.1371
# 705          band  12.599608  13.135759   Topic2  -3.9008   1.1347
# 561      metaphor  10.410603  10.936743   Topic2  -4.0917   1.1271
# 631           sad   9.678540  10.203099   Topic2  -4.1646   1.1236
# 365      software   9.675850  10.202109   Topic2  -4.1648   1.1234
# 228         cover   8.223737   8.737938   Topic2  -4.3275   1.1157
# 864        teetar   5.296982   5.803967   Topic2  -4.7673   1.0850
# 57           feel  12.632771  19.170775   Topic2  -3.8982   0.7593
# 600          play  10.434467  20.934382   Topic2  -4.0894   0.4801
# 239        doctor   8.355481   8.931738   Topic3  -3.8381   1.5831
# 372         study   4.576665   5.118523   Topic3  -4.4401   1.5379
# 324          pant   4.572558   5.119724   Topic3  -4.4410   1.5368
# 225         cough   3.313332   3.848443   Topic3  -4.7631   1.5001
# 275        hernia   3.312956   3.848830   Topic3  -4.7632   1.4999
# 210        cancer   3.311991   3.848644   Topic3  -4.7635   1.4996
# 279          hurt   3.312117   3.848818   Topic3  -4.7635   1.4996
# 89         letter  10.251114  22.744911   Topic3  -3.6337   0.8528
# 263        friend   6.481562  15.089889   Topic3  -4.0921   0.8047
# 68           goal   4.595555  21.314170   Topic3  -4.4360   0.1155
# 165          tell   3.948764  10.274547   Topic3  -4.5876   0.6935
# 110          pass   5.592887   6.168672   Topic4  -3.8879   1.9034
# 10   announcement   2.865842   3.419871   Topic4  -4.5566   1.8247
# 25     blackboard   1.774433   2.320661   Topic4  -5.0359   1.7331
# 7         airport   1.773704   2.320863   Topic4  -5.0363   1.7326
# 75         indian   1.773602   2.320872   Topic4  -5.0364   1.7325
# 106         noise   1.773206   2.321026   Topic4  -5.0366   1.7322
# 122     pollution   1.772813   2.321170   Topic4  -5.0368   1.7319
# 170          time   7.243590  27.192768   Topic4  -3.6293   0.6786
# 149          show   3.966334  10.384585   Topic4  -4.2316   1.0390
# 89         letter   4.535187  22.744911   Topic4  -4.0975   0.3890
# 177          walk   2.320128   4.777437   Topic4  -4.7678   1.2792
# 69           good   3.426649  18.127037   Topic4  -4.3778   0.3356
# 163          talk   2.325013   5.802495   Topic4  -4.7657   1.0869
# 169         thing   2.328496  18.974070   Topic4  -4.7642  -0.0964, token_table=      Topic      Freq          Term
# term
# 7         4  0.861748       airport
# 10        4  0.877226  announcement
# 705       2  0.989665          band
# 25        4  0.861823    blackboard
# 210       3  0.779495        cancer
# ...     ...       ...           ...
# 170       2  0.294196          time
# 170       3  0.036774          time
# 170       4  0.257421          time
# 177       3  0.418634          walk
# 177       4  0.418634          walk
#
# [72 rows x 3 columns], R=7, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1, 4, 3])
