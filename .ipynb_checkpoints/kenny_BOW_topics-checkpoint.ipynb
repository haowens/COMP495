# %%
import pandas as pd
import numpy as np
import json
import glob
import csv
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import spacy
from nltk.corpus import stopwords
import pyLDAvis
import pyLDAvis.gensim
import pyLDAvis.gensim_models

# %%
def load_data(file):
    with open (file, "r", encoding="utf-8") as f:
        data = json.load(f)
    return (data)

def write_data(file, data):
    with open (file, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4)

# %%
stopwords = stopwords.words("english")
stopwords.append("be")
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'be']

# %%
# Load the JSON data from the file
with open("kanan_bag_of_words.json", "r") as file:
    data = json.load(file)

# Get the keys of the JSON object
fields = data.keys()

# Print the fields
print(fields)
# Out:
# dict_keys(['BagOfWords'])

# %%
data = load_data("kanan_bag_of_words.json")['BagOfWords']
print (data[0][0:90])
# print (data[1][0:90])
# Out:
# good,evening,hello,how,are,you,it's,great,to,be,back,in,india,i've,been,traveling,the,worl

# %%
def lemmatization(texts, allowed_postages=["NOUN", "ADJ", "VERB", "ADV"]):
    nlp = nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
    texts_out = []
    for text in data:
        doc = nlp(text)
        new_text = []
        for token in doc:
            if token.pos_ in allowed_postages:
                new_text.append(token.lemma_)
        final = " ".join(new_text)
        texts_out.append(final)
    return (texts_out)

lemmatized_texts = lemmatization(data)
print (lemmatized_texts[0][0:150])
# Out:
# good evening great back in be travel world lot year so good back in need small talk single good thing about look don't know in eye just fucking walk p

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'write', 'make', 'take', 'subject', 're', 'edu', 'use', 'be', 'know', 'go', 'think', 'come', 'see', 'guy', 'say', 'even', 'year', 'one', 'would', 'find', 'get'])
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) 
             if word not in stop_words] for doc in texts]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alisha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def gen_words(data):
    final = []
    for text in data:
        new = gensim.utils.simple_preprocess(text, deacc=True)
        final.append(new)
    return (final)

data_words = gen_words(lemmatized_texts)

print (data_words[0][0:20])
# print (data_words[1][0:20])
# Out:
# ['good', 'evening', 'great', 'back', 'in', 'be', 'travel', 'world', 'lot', 'year', 'so', 'good', 'back', 'in', 'need', 'small', 'talk', 'single', 'good', 'thing']

# %%
data_words = remove_stopwords(data_words)
print(data_words[:1][0][:30])
# Out:
# ['good', 'evening', 'great', 'back', 'travel', 'world', 'lot', 'good', 'back', 'need', 'small', 'talk', 'single', 'good', 'thing', 'look', 'eye', 'fucking', 'walk', 'past', 'deserve', 'interaction', 'case', 'country', 'coffee', 'national', 'sport', 'whole', 'walk', 'first']

# %%
#BIGRAMS AND TRIGRAMS
bigram_phrases = gensim.models.Phrases(data_words, min_count=5, threshold=200)
trigram_phrases = gensim.models.Phrases(bigram_phrases[data_words], threshold=100)

bigram = gensim.models.phrases.Phraser(bigram_phrases)
trigram = gensim.models.phrases.Phraser(trigram_phrases)

def make_bigrams(texts):
    return([bigram[doc] for doc in texts])

def make_trigrams(texts):
    return ([trigram[bigram[doc]] for doc in texts])

data_bigrams = make_bigrams(data_words)
data_bigrams_trigrams = make_trigrams(data_bigrams)

print (data_bigrams_trigrams[0])
# Out:
# ['good', 'evening', 'great', 'back', 'travel', 'world', 'lot', 'good', 'back', 'need', 'small', 'talk', 'single', 'good', 'thing', 'look', 'eye', 'fucking', 'walk', 'past', 'deserve', 'interaction', 'case', 'country', 'coffee', 'national', 'sport', 'whole', 'walk', 'first', 'good', 'thank', 'good', 'hot', 'outside', 'hot', 'begin', 'speak', 'much', 'time', 'population', 'double', 'small', 'talk', 'big', 'talk', 'talk', 'aunty', 'beta', 'yearly', 'salary', 'away', 'long', 'back', 'different', 'airport', 'silent', 'airport', 'announcement', 'airport', 'anymore', 'reason', 'announcement', 'announcement', 'lady', 'gentleman', 'want', 'let', 'happen', 'minute', 'prevent', 'noise', 'pollution', 'snicker', 'big', 'problem', 'running', 'water', 'least', 'die', 'quietly', 'prevent', 'noise', 'pollution', 'announcement', 'people', 'still', 'catch', 'flight', 'send', 'airline', 'personally', 'scream', 'face', 'noise', 'pollution', 'prevent', 'simple', 'announcement', 'goair', 'goa', 'passenger', 'report', 'gate', 'number', 'walk', 'around', 'goair', 'goair', 'goair', 'seem', 'fan', 'airline', 'goair', 'sometimes', 'look', 'particular', 'passenger', 'man', 'standing', 'yelling', 'look', 'couple', 'fight', 'stand', 'leave', 'promise', 'keep', 'thank', 'watch', 'show', 'good', 'time', 'watch', 'comedy', 'indian', 'concepttime', 'pass', 'time', 'pass', 'activity', 'review', 'activity', 'work', 'way', 'time', 'show', 'time', 'bad', 'thing', 'show', 'show', 'feel', 'passage', 'time', 'time', 'pass', 'show', 'mean', 'time', 'pass', 'worry', 'time', 'pastime', 'whole', 'different', 'thing', 'pastime', 'pass', 'time', 'people', 'pastime', 'writing', 'actually', 'read', 'writing', 'time', 'pass', 'first', 'late', 'meeting', 'time', 'relative', 'uncle', 'snicker', 'admit', 'also', 'indian', 'concept', 'way', 'poor', 'joke', 'embodiment', 'much', 'country', 'enjoy', 'suffer', 'tell', 'laugh', 'person', 'become', 'angry', 'derive', 'enjoyment', 'disappointment', 'usually', 'awful', 'pun', 'city', 'enter', 'ethnicity', 'mutter', 'expect', 'laughter', 'teach', 'expect', 'let', 'probably', 'wonder', 'blackboard', 'keep', 'blackboard', 'indian', 'people', 'pay', 'attention', 'blackboard', 'texting', 'exam', 'show', 'show', 'basically', 'letter', 'list', 'goal', 'thing', 'accomplish', 'different', 'age', 'read', 'voice', 'bracket', 'future', 'past', 'lamer', 'remember', 'previous', 'version', 'personality', 'summer', 'shake', 'hand', 'area', 'walk', 'public', 'toilet', 'closed', 'terrible', 'happen', 'previous', 'person', 'leave', 'face', 'letter', 'bracket', 'future', 'goal', 'formal', 'letter', 'remember', 'kind', 'letter', 'formal', 'letter', 'informal', 'letter', 'distinguished', 'format', 'format', 'formal', 'letter', 'comma', 'fucking', 'comma', 'address', 'inside', 'letter', 'reach', 'heh', 'forget', 'mark', 'body', 'letter', 'fuckedup', 'shit', 'want', 'matter', 'end', 'sincerely', 'want', 'romantic', 'word', 'sincerely', 'sincere', 'formal', 'letter', 'informal', 'letter', 'letter', 'friend', 'also', 'correct', 'way', 'wrong', 'way', 'date', 'left', 'date', 'left', 'kind', 'friend', 'scrutinize', 'letter', 'wonder', 'date', 'end', 'friendship', 'practice', 'letter', 'school', 'practice', 'letter', 'address', 'fictional', 'friend', 'live', 'boarding', 'school', 'tone', 'moral', 'superiority', 'always', 'letter', 'friend', 'boarding', 'school', 'encouraging', 'focus', 'study', 'kind', 'friend', 'badly', 'writing', 'letter', 'superior', 'tone', 'dear', 'friend', 'mother', 'tell', 'poorly', 'snicker', 'need', 'great', 'perhaps', 'focus', 'education', 'sincerely', 'sometimes', 'clear', 'tone', 'letter', 'remember', 'exam', 'option', 'letter', 'different', 'option', 'awrite', 'letter', 'friend', 'boarding', 'school', 'wishing', 'happy', 'birthday', 'give', 'present', 'sweet', 'option', 'letter', 'condolence', 'friend', 'lose', 'parent', 'option', 'amount', 'mark', 'choose', 'combine', 'letter', 'happen', 'cover', 'clear', 'pick', 'double', 'mark', 'let ...

# %%
# TF-IDF REMOVAL
from gensim.models import TfidfModel

id2word = corpora.Dictionary(data_bigrams_trigrams)

texts = data_bigrams_trigrams

corpus = [id2word.doc2bow(text) for text in texts]
print (corpus[0][0:20])

tfidf = TfidfModel(corpus, id2word=id2word)

low_value = 0.03
words = []
words_missing_in_tfidf = []
for i in range (0, len(corpus)):
    bow = corpus[i]
    low_value_words = [] # reinitialization to be safe, you can skip this
    tfidf_ids = [id for id, value in bow]
    bow_ids = [id for id, value in bow]
    low_value_words = [id for id, value in tfidf[bow] if value < low_value]
    drops = low_value_words+words_missing_in_tfidf
    for item in drops:
        words.append(id2word[item])
    words_missing_in_tfidf = [id for id in bow_ids if id not in tfidf_ids] # the words with tf-idf score 0 will be missing
    
    new_bow = [b for b in bow if b[0] not in low_value_words and b[0] not in words_missing_in_tfidf]
    corpus[i] = new_bow
# Out:
# [(0, 1), (1, 1), (2, 1), (3, 2), (4, 9), (5, 1), (6, 3), (7, 1), (8, 8), (9, 1), (10, 2), (11, 1), (12, 1), (13, 1), (14, 2), (15, 1), (16, 2), (17, 4), (18, 1), (19, 2)]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, 
                                           id2word=id2word,
                                           num_topics=3,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha="auto")

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.001*"time" + 0.001*"play" + 0.001*"goal" + 0.001*"thing" + 0.001*"letter" + 0.001*"good" + 0.001*"feel" + 0.001*"song" + 0.001*"stab" + 0.001*"people"'),
#  (1,
#   '0.012*"time" + 0.012*"letter" + 0.009*"play" + 0.009*"goal" + 0.009*"thing" + 0.009*"people" + 0.008*"friend" + 0.008*"good" + 0.008*"feel" + 0.008*"dog"'),
#  (2,
#   '0.002*"letter" + 0.002*"time" + 0.002*"people" + 0.002*"goal" + 0.002*"play" + 0.002*"thing" + 0.002*"feel" + 0.002*"good" + 0.002*"band" + 0.002*"song"')]

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word, mds="mmds", R=7)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.037540  0.037507       1        1  99.952238
# 2      0.016654 -0.016513       2        1   0.025059
# 0      0.020886 -0.020994       3        1   0.022703, topic_info=            Term       Freq      Total Category  logprob  loglift
# 845         time  33.000000  33.000000  Default   7.0000   7.0000
# 446       letter  31.000000  31.000000  Default   6.0000   6.0000
# 336         goal  25.000000  25.000000  Default   5.0000   5.0000
# 586       people  23.000000  23.000000  Default   4.0000   4.0000
# 603         play  25.000000  25.000000  Default   3.0000   3.0000
# 838        thing  23.000000  23.000000  Default   2.0000   2.0000
# 283         feel  21.000000  21.000000  Default   1.0000   1.0000
# 845         time  33.436433  33.438710   Topic1  -4.3986   0.0004
# 446       letter  31.635360  31.637609   Topic1  -4.4540   0.0004
# 307       friend  22.729445  22.731322   Topic1  -4.7846   0.0004
# 339         good  22.716317  22.718222   Topic1  -4.7852   0.0004
# 603         play  25.333627  25.335762   Topic1  -4.6761   0.0004
# 336         goal  25.307239  25.309432   Topic1  -4.6772   0.0004
# 838        thing  23.553155  23.555215   Topic1  -4.7490   0.0004
# 586       people  23.493378  23.495569   Topic1  -4.7516   0.0004
# 392  incorrectly   0.000693   1.193864   Topic2  -6.8912   0.8404
# 778        stone   0.000692   1.194057   Topic2  -6.8923   0.8391
# 860        treat   0.000693   1.194462   Topic2  -6.8921   0.8390
# 164         copy   0.000692   1.194621   Topic2  -6.8930   0.8379
# 700         says   0.000691   1.194899   Topic2  -6.8939   0.8368
# 878       unfold   0.000691   1.195028   Topic2  -6.8945   0.8361
# 312     fuckedup   0.000691   1.195061   Topic2  -6.8947   0.8359
# 355        harsh   0.000691   1.195505   Topic2  -6.8944   0.8358
# 586       people   0.001454  23.495569   Topic2  -6.1504  -1.3985
# 336         goal   0.001430  25.309432   Topic2  -6.1674  -1.4898
# 446       letter   0.001502  31.637609   Topic2  -6.1178  -1.6634
# 845         time   0.001473  33.438710   Topic2  -6.1376  -1.7386
# 603         play   0.001368  25.335762   Topic2  -6.2114  -1.5349
# 838        thing   0.001300  23.555215   Topic2  -6.2621  -1.5127
# 283         feel   0.001221  21.784731   Topic2  -6.3251  -1.4976
# 402   instrument   0.000652   1.195552   Topic3  -6.8538   0.8763
# 778        stone   0.000651   1.194057   Topic3  -6.8557   0.8757
# 789      succeed   0.000651   1.195632   Topic3  -6.8547   0.8754
# 392  incorrectly   0.000650   1.193864   Topic3  -6.8562   0.8753
# 37        anyway   0.000651   1.195368   Topic3  -6.8550   0.8753
# 619        press   0.000652   1.197004   Topic3  -6.8538   0.8751
# 804      surgeon   0.000651   1.195475   Topic3  -6.8554   0.8748
# 525        naked   0.000651   1.196242   Topic3  -6.8548   0.8747
# 209   distribute   0.000652   1.197726   Topic3  -6.8539   0.8744
# 13     afterlife   0.000652   1.197896   Topic3  -6.8540   0.8742
# 168        could   0.000652   1.198068   Topic3  -6.8541   0.8740
# 67          base   0.000652   1.198845   Topic3  -6.8538   0.8736
# 320     gangster   0.000652   1.200112   Topic3  -6.8543   0.8720
# 845         time   0.000805  33.438710   Topic3  -6.6431  -2.2441
# 603         play   0.000767  25.335762   Topic3  -6.6908  -2.0142
# 336         goal   0.000764  25.309432   Topic3  -6.6959  -2.0183
# 838        thing   0.000759  23.555215   Topic3  -6.7013  -1.9518
# 754         song   0.000740  17.280718   Topic3  -6.7276  -1.6684
# 765         stab   0.000739  18.265492   Topic3  -6.7284  -1.7247
# 339         good   0.000743  22.718222   Topic3  -6.7226  -1.9370
# 446       letter   0.000746  31.637609   Topic3  -6.7192  -2.2648
# 283         feel   0.000741  21.784731   Topic3  -6.7252  -1.8976, token_table=      Topic      Freq         Term
# term
# 13        1  0.834797    afterlife
# 37        1  0.836563       anyway
# 67        1  0.834136         base
# 164       1  0.837085         copy
# 168       1  0.834677        could
# 209       1  0.834915   distribute
# 283       1  1.009882         feel
# 307       1  1.011820       friend
# 312       1  0.836777     fuckedup
# 320       1  0.833255     gangster
# 336       1  0.987774         goal
# 339       1  1.012403         good
# 355       1  0.836467        harsh
# 392       1  0.837616  incorrectly
# 402       1  0.836434   instrument
# 446       1  1.011454       letter
# 525       1  0.835951        naked
# 586       1  0.978908       people
# 603       1  0.986748         play
# 619       1  0.835419        press
# 700       1  0.836891         says
# 754       1  0.983755         song
# 765       1  0.985465         stab
# 778       1  0.837481        stone
# 789       1  0.836378      succeed
# 804       1  0.836488      surgeon
# 838       1  1.018883        thing
# 845       1  0.986880         time
# 860       1  0.837197        treat
# 878       1  0.836801       unfold, R=7, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 3, 1])
