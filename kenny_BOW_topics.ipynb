# %%
import pandas as pd
import numpy as np
import json
import glob
import csv
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import spacy
from nltk.corpus import stopwords
import pyLDAvis
import pyLDAvis.gensim
import pyLDAvis.gensim_models
# Out:
# /var/folders/d9/sbfhfygx5vx9mlfxxhcxrb280000gn/T/ipykernel_10869/2475999428.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def load_data(file):
    with open (file, "r", encoding="utf-8") as f:
        data = json.load(f)
    return (data)

def write_data(file, data):
    with open (file, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4)

# %%
stopwords = stopwords.words("english")
stopwords.append("be")
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'be']

# %%
# Load the JSON data from the file
with open("kenny_bag_of_words.json", "r") as file:
    data = json.load(file)

# Get the keys of the JSON object
fields = data.keys()

# Print the fields
print(fields)
# Out:
# dict_keys(['BagOfWords'])

# %%
data = load_data("kenny_bag_of_words.json")['BagOfWords']
print (data[0][0:90])
# print (data[1][0:90])
# Out:
# oh,my,god,thank,you,so,much,mumbai,thank,you,thank,you,really,how,are,you,guys,doing,oh,sh

# %%
def lemmatization(texts, allowed_postages=["NOUN", "ADJ", "VERB", "ADV"]):
    nlp = nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
    texts_out = []
    for text in data:
        doc = nlp(text)
        new_text = []
        for token in doc:
            if token.pos_ in allowed_postages:
                new_text.append(token.lemma_)
        final = " ".join(new_text)
        texts_out.append(final)
    return (texts_out)

lemmatized_texts = lemmatization(data)
print (lemmatized_texts[0][0:150])
# Out:
# thank so much mumbai thank thank really guy do come on guy royal opera house guy royal opera house big deal know none know history big deal take bath

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'bro', 'happen', 'talk', 'want', 'nice', 'good', 'need', 'people', 'put', 'thing', 'look', 'write', 'make', 'take', 'subject', 're', 'edu', 'use', 'be', 'know', 'go', 'think', 'come', 'see', 'guy', 'say', 'even', 'year', 'one', 'would', 'find', 'get'])
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) 
             if word not in stop_words] for doc in texts]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alisha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def gen_words(data):
    final = []
    for text in data:
        new = gensim.utils.simple_preprocess(text, deacc=True)
        final.append(new)
    return (final)

data_words = gen_words(lemmatized_texts)

print (data_words[0][0:20])
# print (data_words[1][0:20])
# Out:
# ['thank', 'so', 'much', 'mumbai', 'thank', 'thank', 'really', 'guy', 'do', 'come', 'on', 'guy', 'royal', 'opera', 'house', 'guy', 'royal', 'opera', 'house', 'big']

# %%
data_words = remove_stopwords(data_words)
print(data_words[:1][0][:30])
# Out:
# ['thank', 'much', 'mumbai', 'thank', 'thank', 'really', 'royal', 'opera', 'house', 'royal', 'opera', 'house', 'big', 'deal', 'none', 'history', 'big', 'deal', 'bath', 'twice', 'possible', 'apparently', 'royal', 'opera', 'house', 'great', 'deal', 'big', 'occasion', 'cheer']

# %%
#BIGRAMS AND TRIGRAMS
bigram_phrases = gensim.models.Phrases(data_words, min_count=5, threshold=200)
trigram_phrases = gensim.models.Phrases(bigram_phrases[data_words], threshold=100)

bigram = gensim.models.phrases.Phraser(bigram_phrases)
trigram = gensim.models.phrases.Phraser(trigram_phrases)

def make_bigrams(texts):
    return([bigram[doc] for doc in texts])

def make_trigrams(texts):
    return ([trigram[bigram[doc]] for doc in texts])

data_bigrams = make_bigrams(data_words)
data_bigrams_trigrams = make_trigrams(data_bigrams)

print (data_bigrams_trigrams[0])
# Out:
# ['thank', 'much', 'mumbai', 'thank', 'thank', 'really', 'royal', 'opera', 'house', 'royal', 'opera', 'house', 'big', 'deal', 'none', 'history', 'big', 'deal', 'bath', 'twice', 'possible', 'apparently', 'royal', 'opera', 'house', 'great', 'deal', 'big', 'occasion', 'cheer', 'die', 'soon', 'die', 'soon', 'crazy', 'believe', 'kind', 'difficult', 'dance', 'much', 'dance', 'care', 'else', 'way', 'dance', 'dance', 'watch', 'apply', 'woman', 'great', 'dancing', 'man', 'stop', 'man', 'standing', 'dancing', 'enough', 'bar', 'music', 'dance', 'dancing', 'painful', 'watch', 'club', 'great', 'already', 'fun', 'already', 'high', 'great', 'spending', 'buck', 'drink', 'club', 'drink', 'way', 'drink', 'whatever', 'high', 'neat', 'neat', 'neat', 'neat', 'awesome', 'jack', 'coke', 'diet', 'diet', 'kind', 'barbaric', 'place', 'great', 'chance', 'still', 'high', 'shots', 'sir', 'kind', 'shots', 'sir', 'many', 'stop', 'shout', 'stop', 'care', 'like', 'shot', 'petroleum', 'petroleum', 'shot', 'bad', 'environment', 'dancing', 'awesome', 'dance', 'club', 'friend', 'loud', 'table', 'care', 'friend', 'night', 'never', 'feel', 'cold', 'ego', 'keep', 'warm', 'grow', 'old', 'become', 'open', 'minded', 'lose', 'neck', 'book', 'today', 'enter', 'club', 'circle', 'awesomely', 'unique', 'idea', 'awesome', 'idea', 'book', 'brain', 'together', 'leg', 'leg', 'forget', 'bollywood', 'arjun', 'practise', 'fine', 'new', 'centre', 'solo', 'dance', 'centre', 'centre', 'many', 'rule', 'shot', 'awesome', 'dance', 'though', 'dance', 'awhile', 'club', 'beat', 'shake', 'remember', 'pay', 'rent', 'stop', 'deduct', 'soul', 'certain', 'advantage', 'though', 'confidently', 'friend', 'parent', 'left', 'ironic', 'give', 'shit', 'genuinely', 'parent', 'hate', 'care', 'annoying', 'care', 'much', 'party', 'least', 'eat', 'mom', 'care', 'nutrition', 'much', 'mom', 'late', 'party', 'mom', 'many', 'door', 'house', 'hate', 'mom', 'hogwart', 'never', 'let', 'follow', 'dream', 'certain', 'stage', 'anymore', 'job', 'stage', 'bad', 'show', 'still', 'feel', 'shy', 'though', 'around', 'really', 'pretty', 'woman', 'feel', 'awkward', 'mean', 'reaction', 'worry', 'feel', 'shy', 'today', 'fine', 'comedian', 'joke', 'woman', 'like', 'really', 'freaking', 'shit', 'lighting', 'give', 'bathroom', 'light', 'show', 'son', 'bitch', 'dare', 'dare', 'pretty', 'enough', 'much', 'face', 'mother', 'recognise', 'eye', 'liner', 'eyelash', 'sun', 'roof', 'bitch', 'dare', 'pretty', 'enough', 'seem', 'eye', 'shadow', 'light', 'dark', 'dark', 'light', 'dimensional', 'eye', 'shadow', 'son', 'bitch', 'meet', 'grandfather', 'straightened', 'hair', 'lost', 'finger', 'still', 'climb', 'himalayas', 'son', 'joke', 'joke', 'woman', 'reinvent', 'whenever', 'anywhere', 'well', 'new', 'venue', 'new', 'place', 'enter', 'bathroom', 'new', 'person', 'like', 'excuse', 'friend', 'crazy', 'inside', 'bathroom', 'first', 'question', 'really', 'wash', 'hand', 'second', 'wear', 'clothe', 'old', 'naked', 'dad', 'home', 'dad', 'hate', 'wear', 'clothe', 'hate', 'wear', 'clothe', 'guest', 'home', 'mom', 'impression', 'dad', 'wear', 'clothe', 'bear', 'wild', 'teaching', 'live', 'civilisation', 'true', 'evolutionary', 'stage', 'man', 'dance', 'naked', 'feel', 'shy', 'around', 'woman', 'really', 'pretty', 'intimidating', 'woman', 'player', 'sorry', 'sorry', 'stupid', 'shy', 'shit', 'shy', 'dictionary', 'hot', 'step', 'road', 'truck', 'full', 'woman', 'thank', 'moonwalk', 'home', 'cool', 'shy', 'shy', 'hate', 'ask', 'opinion', 'group', 'amazing', 'amazing', 'conversation', 'moment', 'group', 'bad', 'woman', 'date', 'boyfriend', 'super', 'emotional', 'mean', 'world', 'hold', 'hand', 'hold', 'hand', 'past', 'month', 'become', 'month', 'finger', 'finger', 'friend', 'gopal', 'friend', 'month', 'feel', 'life', 'time', 'baby', 'physical', 'cuddling', 'feel', 'warm', 'well', 'parent', 'tell', 'story', 'tell', 'baby', 'princess', 'prince', 'suddenly', 'friend', 'neha', 'clingy', 'emo', 'emo', 'drink', 'many', 'door', 'house', 'man', 'hogwart', 'part ...

# %%
# TF-IDF REMOVAL
from gensim.models import TfidfModel

id2word = corpora.Dictionary(data_bigrams_trigrams)

texts = data_bigrams_trigrams

corpus = [id2word.doc2bow(text) for text in texts]
print (corpus[0][0:20])

tfidf = TfidfModel(corpus, id2word=id2word)

low_value = 0.03
words = []
words_missing_in_tfidf = []
for i in range (0, len(corpus)):
    bow = corpus[i]
    low_value_words = [] # reinitialization to be safe, you can skip this
    tfidf_ids = [id for id, value in bow]
    bow_ids = [id for id, value in bow]
    low_value_words = [id for id, value in tfidf[bow] if value < low_value]
    drops = low_value_words+words_missing_in_tfidf
    for item in drops:
        words.append(id2word[item])
    words_missing_in_tfidf = [id for id in bow_ids if id not in tfidf_ids] # the words with tf-idf score 0 will be missing
    
    new_bow = [b for b in bow if b[0] not in low_value_words and b[0] not in words_missing_in_tfidf]
    corpus[i] = new_bow
# Out:
# [(0, 1), (1, 3), (2, 2), (3, 2), (4, 1), (5, 1), (6, 1), (7, 1), (8, 1), (9, 2), (10, 1), (11, 2), (12, 1), (13, 1), (14, 1), (15, 5), (16, 9), (17, 1), (18, 6), (19, 1)]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, 
                                           id2word=id2word,
                                           num_topics=3,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha="auto")

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.011*"mom" + 0.008*"woman" + 0.008*"house" + 0.007*"home" + 0.006*"great" + 0.006*"give" + 0.006*"time" + 0.005*"man" + 0.005*"bottle" + 0.005*"dance"'),
#  (1,
#   '0.002*"mom" + 0.002*"house" + 0.002*"woman" + 0.002*"give" + 0.002*"home" + 0.002*"great" + 0.002*"dance" + 0.002*"awesome" + 0.002*"die" + 0.002*"water"'),
#  (2,
#   '0.002*"mom" + 0.002*"house" + 0.002*"great" + 0.002*"woman" + 0.001*"home" + 0.001*"give" + 0.001*"die" + 0.001*"time" + 0.001*"sorry" + 0.001*"feel"')]

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word, mds="mmds", R=10)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.026320  0.026224       1        1  99.903430
# 1      0.012725 -0.012621       2        1   0.052455
# 2      0.013596 -0.013603       3        1   0.044115, topic_info=      Term       Freq      Total Category  logprob  loglift
# 456    mom  21.000000  21.000000  Default  10.0000  10.0000
# 353  house  15.000000  15.000000  Default   9.0000   9.0000
# 791  woman  15.000000  15.000000  Default   8.0000   8.0000
# 348   home  13.000000  13.000000  Default   7.0000   7.0000
# 308   give  11.000000  11.000000  Default   6.0000   6.0000
# ..     ...        ...        ...      ...      ...      ...
# 308   give   0.001242  11.664455   Topic3  -6.5278  -1.4217
# 731   time   0.001229  10.821233   Topic3  -6.5379  -1.3568
# 348   home   0.001244  13.446092   Topic3  -6.5256  -1.5616
# 668  sorry   0.001201   8.185409   Topic3  -6.5614  -1.1011
# 272   feel   0.001195   9.072058   Topic3  -6.5662  -1.2087
#
# [64 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 21        1  0.853318       angel
# 54        1  0.979724     awesome
# 76        1  0.853671    bedsheet
# 88        1  1.005585      bottle
# 97        1  0.852262      bronze
# 112       1  0.852319       carry
# 121       1  0.852807      change
# 134       1  0.853425      cliche
# 183       1  1.006982       dance
# 204       1  0.853689  dictionary
# 206       1  1.007471         die
# 218       1  0.852509         doe
# 261       1  0.852711     explode
# 272       1  0.992057        feel
# 308       1  1.028766        give
# 315       1  1.028549       great
# 333       1  0.851416        hard
# 348       1  0.966824        home
# 353       1  0.988385       house
# 358       1  0.850980   hydrating
# 394       1  0.853239        lame
# 398       1  0.853649         lay
# 434       1  1.003817         man
# 456       1  0.984475         mom
# 460       1  0.853307    moonwalk
# 467       1  0.852075      mumbai
# 520       1  0.852695        past
# 596       1  0.852288        road
# 597       1  0.853102        roof
# 643       1  0.852794        sick
# 655       1  0.852815       sleep
# 668       1  0.977349       sorry
# 730       1  0.853368       throw
# 731       1  1.016520        time
# 740       1  0.958974       train
# 742       1  0.850765    trifacta
# 764       1  0.852911     wailing
# 774       1  0.994033       water
# 791       1  0.986934       woman, R=10, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3])

# %%
import re
# Load JSON data from file
with open('kenny_transcripts.json', 'r') as file:
    data = json.load(file)

# Extract transcripts from JSON data
transcripts = data.get('Transcripts', [])

# Iterate over each transcript
for transcript in transcripts:
    # Split the transcript into sentences
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', transcript)
    
    # Iterate over each sentence
    for sentence in sentences:
        # Check if 'friend' is in the sentence
        if 'die' in sentence.lower():
            print(sentence)
# Out:
# Because they’re like, “Hey, he’s going to die soon.
# Yaay!” Yea, I am going to die soon.
# “Can I have a Jack and Coke but diet Coke, please.
# Oh they don’t have diet Coke.
# [man from audience] Housekeeping.
# We’re like, “Why aren’t you coming to work for two days?” “Someone straight up died in my house.” “Who died in your house?” “Don’t know, some guy came over at night and didn’t wake up in the morning.” Okay.
# Why may I ask?” “Oh, actually someone passed away in her house.” “Oh, last week also two people died.
# Diwali festival also ten people will die or what?” I’m like, “Woah! Calm down.” The worst culprit of this is my mom.
# They deserve to die.” What is so important that as they are dying they’re like, “Bro! Can you just tell me that middle class restaurant joke…” It’s a self referential joke.
# The next thing I’m going to do, I’m going to make an indie love song for you guys.
# Oh, they die literally.
# So basically, an indie love song is in right now.
# Indie is independent music, anything that is not mainstream is indie.
# So I am going to make an indie love song but you need two things.
# Bottle, water bottle.” Want to make it more indie?
# Night… Morning… Evening… Early Afternoon…” Do you want to make it more indie?
# I need audience participation up in this shit.
# You guys are an awesome audience, even you guys.
# I need you guys because indie musicians, they don’t have money, they have audience.
# You need audience participation.
# Every music concert, there will be this one part where the band is going to be like, “Okay guys, for this next song, we need the audience.
# Sometimes the audience is little too confident.
# Guys, do you want to make it more indie?
# I look out the window.” True indie songs, they stop mid-sentence.
# You’ve been a lovely audience.
# Because the last audience didn’t stand up.
